# %%
from dotenv import load_dotenv

load_dotenv('../../.env')
# Out:
# True

# %% [markdown]
# # Set Environment

# %%
import os
import getpass
from langchain.vectorstores import DeepLake
from langchain_community.embeddings import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(model_name = 'sentence-transformers/all-MiniLM-L6-v2',
                                       model_kwargs = {'device':'cpu'} )

# %% [markdown]
# # Indexing the Twitter Algorithm Code Base

# %%
import os
from langchain.document_loaders import TextLoader

root_dir = './the-algorithm'
docs = []
for dirpath, dirnames, filenames in os.walk(root_dir):
    for file in filenames:
        try: 
            loader = TextLoader(os.path.join(dirpath, file), encoding='utf-8')
            docs.extend(loader.load_and_split())
        except Exception as e: 
            pass

# %% [markdown]
# ## Divide to Chunks

# %%
from langchain.text_splitter import CharacterTextSplitter

text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
texts = text_splitter.split_documents(docs)
# Out:
# Created a chunk of size 2549, which is longer than the specified 1000
# Created a chunk of size 2095, which is longer than the specified 1000
# Created a chunk of size 1983, which is longer than the specified 1000
# Created a chunk of size 1020, which is longer than the specified 1000
# Created a chunk of size 1540, which is longer than the specified 1000
# Created a chunk of size 1245, which is longer than the specified 1000
# Created a chunk of size 1257, which is longer than the specified 1000
# Created a chunk of size 2273, which is longer than the specified 1000
# Created a chunk of size 1411, which is longer than the specified 1000
# Created a chunk of size 1263, which is longer than the specified 1000
# Created a chunk of size 1672, which is longer than the specified 1000
# Created a chunk of size 1794, which is longer than the specified 1000
# Created a chunk of size 1034, which is longer than the specified 1000
# Created a chunk of size 1201, which is longer than the specified 1000
# Created a chunk of size 1191, which is longer than the specified 1000
# Created a chunk of size 1274, which is longer than the specified 1000
# Created a chunk of size 1403, which is longer than the specified 1000
# Created a chunk of size 1146, which is longer than the specified 1000
# Created a chunk of size 1348, which is longer than the specified 1000
# Created a chunk of size 1058, which is longer than the specified 1000
# Created a chunk of size 2569, which is longer than the specified 1000
# Created a chunk of size 1282, which is longer than the specified 1000
# Created a chunk of size 2735, which is longer than the specified 1000
# Created a chunk of size 1594, which is longer than the specified 1000
# Created a chunk of size 1113, which is longer than the specified 1000
# Created a chunk of size 1386, which is longer than the specified 1000
# Created a chunk of size 1424, which is longer than the specified 1000
# Created a chunk of size 1006, which is longer than the specified 1000
# Created a chunk of size 1553, which is longer than the specified 1000
# Created a chunk of size 1478, which is longer than the specified 1000
# Created a chunk of size 2878, which is longer than the specified 1000
# Created a chunk of size 2036, which is longer than the specified 1000
# Created a chunk of size 1361, which is longer than the specified 1000
# Created a chunk of size 1187, which is longer than the specified 1000
# Created a chunk of size 1276, which is longer than the specified 1000
# Created a chunk of size 1493, which is longer than the specified 1000
# Created a chunk of size 1184, which is longer than the specified 1000
# Created a chunk of size 1019, which is longer than the specified 1000
# Created a chunk of size 1880, which is longer than the specified 1000
# Created a chunk of size 2674, which is longer than the specified 1000
# Created a chunk of size 1403, which is longer than the specified 1000
# Created a chunk of size 1808, which is longer than the specified 1000
# Created a chunk of size 1569, which is longer than the specified 1000
# Created a chunk of size 1009, which is longer than the specified 1000
# Created a chunk of size 1112, which is longer than the specified 1000
# Created a chunk of size 1273, which is longer than the specified 1000
# Created a chunk of size 1069, which is longer than the specified 1000
# Created a chunk of size 2464, which is longer than the specified 1000
# Created a chunk of size 1090, which is longer than the specified 1000
# Created a chunk of size 1012, which is longer than the specified 1000
# Created a chunk of size 2856, which is longer than the specified 1000
# Created a chunk of size 1298, which is longer than the specified 1000
# Created a chunk of size 1017, which is longer than the specified 1000
# Created a chunk of size 2441, which is longer than the specified 1000
# Created a chunk of size 1120, which is longer than the specified 1000
# Created a chunk of size 1046, which is longer than the specified 1000
# Created a chunk of size 1882, which is longer than the specified 1000
# Created a chunk of size 1950, which is longer than the specified 1000
# Created a chunk of size 1089, which is longer than the specified 1000
# Created a chunk of size 1113, which is longer than the specified 1000
# Created a chunk of size 1462, which is longer than the specified 1000
# Created a chunk of size 1363, which is longer than the specified 1000
# Created a chunk of size 2234, which is longer than the specified 1000
# Created a chunk of size 1189, which is longer than the specified 1000
# Created a chunk of size 2226, which is longer than the specified 1000
# Created a chunk of size 1726, which is longer than the specified 1000
# Created a chunk of size 1041, which is longer than the specified 1000
# Created a chunk of size 1609, which is longer than the specified 1000
# Created a chunk of size 1336, which is longer than the specified 1000
# Created a chunk of size 1350, which is longer than the specified 1000
# Created a chunk of size 1265, which is longer than the specified 1000
# Created a chunk of size 1310, which is longer than the specified 1000
# Created a chunk of size 1034, which is longer than the specified 1000
# Created a chunk of size 1032, which is longer than the specified 1000
# Created a chunk of size 1004, which is longer than the specified 1000
# Created a chunk of size 1126, which is longer than the specified 1000
# Created a chunk of size 2336, which is longer than the specified 1000
# Created a chunk of size 1277, which is longer than the specified 1000
# Created a chunk of size 1005, which is longer than the specified 1000
# Created a chunk of size 1157, which is longer than the specified 1000
# Created a chunk of size 1151, which is longer than the specified 1000
# Created a chunk of size 1033, which is longer than the specified 1000
# Created a chunk of size 1035, which is longer than the specified 1000
# Created a chunk of size 1600, which is longer than the specified 1000
# Created a chunk of size 1020, which is longer than the specified 1000
# Created a chunk of size 1485, which is longer than the specified 1000
# Created a chunk of size 1572, which is longer than the specified 1000
# Created a chunk of size 1024, which is longer than the specified 1000
# Created a chunk of size 1214, which is longer than the specified 1000
# Created a chunk of size 1093, which is longer than the specified 1000
# Created a chunk of size 2382, which is longer than the specified 1000
# Created a chunk of size 1659, which is longer than the specified 1000
# Created a chunk of size 1188, which is longer than the specified 1000
# Created a chunk of size 1020, which is longer than the specified 1000
# Created a chunk of size 1136, which is longer than the specified 1000
# Created a chunk of size 1254, which is longer than the specified 1000
# Created a chunk of size 1089, which is longer than the specified 1000
# Created a chunk of size 1104, which is longer than the specified 1000
# Created a chunk of size 1236, which is longer than the specified 1000
# Created a chunk of size 1270, which is longer than the specified 1000
# Created a chunk of size 1205, which is longer than the specified 1000
# Created a chunk of size 1214, which is longer than the specified 1000
# Created a chunk of size 1449, which is longer than the specified 1000
# Created a chunk of size 1287, which is longer than the specified 1000
# Created a chunk of size 2233, which is longer than the specified 1000
# Created a chunk of size 1183, which is longer than the specified 1000
# Created a chunk of size 1210, which is longer than the specified 1000
# Created a chunk of size 1201, which is longer than the specified 1000
# Created a chunk of size 1243, which is longer than the specified 1000
# Created a chunk of size 1468, which is longer than the specified 1000
# Created a chunk of size 1477, which is longer than the specified 1000
# Created a chunk of size 1477, which is longer than the specified 1000
# Created a chunk of size 1577, which is longer than the specified 1000
# Created a chunk of size 1860, which is longer than the specified 1000
# Created a chunk of size 1322, which is longer than the specified 1000
# Created a chunk of size 1399, which is longer than the specified 1000
# Created a chunk of size 1042, which is longer than the specified 1000
# Created a chunk of size 1350, which is longer than the specified 1000
# Created a chunk of size 1136, which is longer than the specified 1000
# Created a chunk of size 1658, which is longer than the specified 1000
# Created a chunk of size 1135, which is longer than the specified 1000
# Created a chunk of size 1123, which is longer than the specified 1000
# Created a chunk of size 1483, which is longer than the specified 1000
# Created a chunk of size 1651, which is longer than the specified 1000
# Created a chunk of size 1371, which is longer than the specified 1000
# Created a chunk of size 1123, which is longer than the specified 1000
# Created a chunk of size 1085, which is longer than the specified 1000
# Created a chunk of size 1300, which is longer than the specified 1000
# Created a chunk of size 1730, which is longer than the specified 1000
# Created a chunk of size 1260, which is longer than the specified 1000
# Created a chunk of size 2134, which is longer than the specified 1000
# Created a chunk of size 1806, which is longer than the specified 1000
# Created a chunk of size 1972, which is longer than the specified 1000
# Created a chunk of size 1231, which is longer than the specified 1000
# Created a chunk of size 1008, which is longer than the specified 1000
# Created a chunk of size 1090, which is longer than the specified 1000
# Created a chunk of size 1425, which is longer than the specified 1000
# Created a chunk of size 1228, which is longer than the specified 1000
# Created a chunk of size 1458, which is longer than the specified 1000
# Created a chunk of size 1224, which is longer than the specified 1000
# Created a chunk of size 1187, which is longer than the specified 1000
# Created a chunk of size 1445, which is longer than the specified 1000
# Created a chunk of size 3103, which is longer than the specified 1000
# Created a chunk of size 1660, which is longer than the specified 1000
# Created a chunk of size 1340, which is longer than the specified 1000
# Created a chunk of size 1145, which is longer than the specified 1000
# Created a chunk of size 1201, which is longer than the specified 1000
# Created a chunk of size 1145, which is longer than the specified 1000
# Created a chunk of size 1051, which is longer than the specified 1000
# Created a chunk of size 1064, which is longer than the specified 1000
# Created a chunk of size 1151, which is longer than the specified 1000
# Created a chunk of size 1131, which is longer than the specified 1000
# Created a chunk of size 1685, which is longer than the specified 1000
# Created a chunk of size 1792, which is longer than the specified 1000
# Created a chunk of size 1385, which is longer than the specified 1000
# Created a chunk of size 1442, which is longer than the specified 1000
# Created a chunk of size 1114, which is longer than the specified 1000
# Created a chunk of size 1084, which is longer than the specified 1000
# Created a chunk of size 1120, which is longer than the specified 1000
# Created a chunk of size 2011, which is longer than the specified 1000
# Created a chunk of size 1534, which is longer than the specified 1000
# Created a chunk of size 1543, which is longer than the specified 1000
# Created a chunk of size 1746, which is longer than the specified 1000
# Created a chunk of size 1020, which is longer than the specified 1000
# Created a chunk of size 1122, which is longer than the specified 1000
# Created a chunk of size 1257, which is longer than the specified 1000
# Created a chunk of size 1493, which is longer than the specified 1000
# Created a chunk of size 1535, which is longer than the specified 1000
# Created a chunk of size 1004, which is longer than the specified 1000
# Created a chunk of size 1484, which is longer than the specified 1000

# %%
username = "thapabibek1129" # replace with your username from app.activeloop.ai
db = DeepLake(dataset_path=f"hub://{username}/twitter-algorithm", embedding_function=embeddings)
db.add_documents(texts)
# Out:
# Your Deep Lake dataset has been successfully created!
# Creating 2799 embeddings in 6 batches of size 500:: 100%|██████████| 6/6 [08:08<00:00, 81.49s/it]
# Dataset(path='hub://thapabibek1129/twitter-algorithm', tensors=['text', 'metadata', 'embedding', 'id'])
#
#   tensor      htype       shape      dtype  compression
#   -------    -------     -------    -------  -------
#    text       text      (2799, 1)     str     None
#  metadata     json      (2799, 1)     str     None
#  embedding  embedding  (2799, 384)  float32   None
#     id        text      (2799, 1)     str     None
# ['4f60f69f-c9b6-11ee-9644-a434d9523559',
#  '4f60f6a0-c9b6-11ee-b5a0-a434d9523559',
#  '4f60f6a1-c9b6-11ee-bddb-a434d9523559',
#  '4f60f6a2-c9b6-11ee-8a14-a434d9523559',
#  '4f60f6a3-c9b6-11ee-a348-a434d9523559',
#  '4f60f6a4-c9b6-11ee-997a-a434d9523559',
#  '4f60f6a5-c9b6-11ee-abba-a434d9523559',
#  '4f60f6a6-c9b6-11ee-b6d9-a434d9523559',
#  '4f60f6a7-c9b6-11ee-bc5b-a434d9523559',
#  '4f60f6a8-c9b6-11ee-9ebe-a434d9523559',
#  '4f60f6a9-c9b6-11ee-a8ae-a434d9523559',
#  '4f60f6aa-c9b6-11ee-8cff-a434d9523559',
#  '4f60f6ab-c9b6-11ee-aa8b-a434d9523559',
#  '4f60f6ac-c9b6-11ee-99fb-a434d9523559',
#  '4f60f6ad-c9b6-11ee-b6e5-a434d9523559',
#  '4f60f6ae-c9b6-11ee-aa3f-a434d9523559',
#  '4f60f6af-c9b6-11ee-a7e1-a434d9523559',
#  '4f60f6b0-c9b6-11ee-b1f0-a434d9523559',
#  '4f60f6b1-c9b6-11ee-aca5-a434d9523559',
#  '4f611f0d-c9b6-11ee-9f74-a434d9523559',
#  '4f611f0e-c9b6-11ee-9bc6-a434d9523559',
#  '4f611f0f-c9b6-11ee-8aea-a434d9523559',
#  '4f611f10-c9b6-11ee-9d86-a434d9523559',
#  '4f611f11-c9b6-11ee-9384-a434d9523559',
#  '4f611f12-c9b6-11ee-a9b1-a434d9523559',
#  '4f611f13-c9b6-11ee-9017-a434d9523559',
#  '4f611f14-c9b6-11ee-a63a-a434d9523559',
#  '4f611f15-c9b6-11ee-8727-a434d9523559',
#  '4f611f16-c9b6-11ee-a1f7-a434d9523559',
#  '4f611f17-c9b6-11ee-95ee-a434d9523559',
#  '4f611f18-c9b6-11ee-99af-a434d9523559',
#  '4f611f19-c9b6-11ee-a892-a434d9523559',
#  '4f611f1a-c9b6-11ee-b385-a434d9523559',
#  '4f611f1b-c9b6-11ee-a828-a434d9523559',
#  '4f611f1c-c9b6-11ee-8a5a-a434d9523559',
#  '4f611f1d-c9b6-11ee-9890-a434d9523559',
#  '4f611f1e-c9b6-11ee-9693-a434d9523559',
retriever = db.as_retriever()
retriever.search_kwargs['distance_metric'] = 'cos'
retriever.search_kwargs['fetch_k'] = 100
retriever.search_kwargs['k'] = 10

# %% [markdown]
# # Using DeepLake Filters

# %%
def filter(x):
    if 'com.google' in x['text'].data()['value']:
        return False
    metadata = x['metadata'].data()['value']
    return 'scala' in metadata['source'] or 'py' in metadata['source']

# %% [markdown]
# # Connect to HugginFace models

# %%
from langchain import HuggingFaceHub

llm_mistral = HuggingFaceHub(
    repo_id='mistralai/Mistral-7B-Instruct-v0.2',
    model_kwargs={'temperature':0.5,"max_length": 64,"max_new_tokens":512}
)
# Out:
# c:\Users\Ghost\anaconda3\envs\genai360\lib\site-packages\huggingface_hub\utils\_deprecation.py:131: FutureWarning: 'InferenceApi' (from 'huggingface_hub.inference_api') is deprecated and will be removed from version '1.0'. `InferenceApi` client is deprecated in favor of the more feature-complete `InferenceClient`. Check out this guide to learn how to convert your script to use it: https://huggingface.co/docs/huggingface_hub/guides/inference#legacy-inferenceapi-client.
#   warnings.warn(warning_message, FutureWarning)

# %%
from langchain.chains import ConversationalRetrievalChain

qa_mistral = ConversationalRetrievalChain.from_llm(llm_mistral,retriever=retriever)

# %% [markdown]
# # Ask Questions

# %%
questions = [
    "What does favCountParams do?",
    "is it Likes + Bookmarks, or not clear from the code?",
    "What are the major negative modifiers that lower your linear ranking parameters?",   
    "How do you get assigned to SimClusters?",
    "What is needed to migrate from one SimClusters to another SimClusters?",
    "How much do I get boosted within my cluster?",   
    "How does Heavy ranker work. what are it’s main inputs?",
    "How can one influence Heavy ranker?",
    "why threads and long tweets do so well on the platform?",
    "Are thread and long tweet creators building a following that reacts to only threads?",
    "Do you need to follow different strategies to get most followers vs to get most likes and bookmarks per tweet?",
    "Content meta data and how it impacts virality (e.g. ALT in images).",
    "What are some unexpected fingerprints for spam factors?",
    "Is there any difference between company verified checkmarks and blue verified individual checkmarks?",
]

# %%
chat_history = []

for question in questions:  
    result = qa_mistral({"question": question, "chat_history": chat_history})
    chat_history.append((question, result['answer']))
    print(f"-> **Question**: {question} \n")
    print(f"**Answer**: {result['answer']} \n")
# Out:
# -> **Question**: What does favCountParams do?
#
# **Answer**:  The context does not provide enough information to answer the question directly. The code snippet includes several FSParam and FSBoundedParam definitions with names that include "favCount", but it's not clear what those parameters are used for or how they relate to each other. Without additional context or documentation, it's impossible to determine the exact purpose of "favCountParams".
#
# -> **Question**: is it Likes + Bookmarks, or not clear from the code?
#
# **Answer**:
# Based on the code snippet provided, it is not clear whether 'favCountParams' represents the total of 'Likes' and 'Bookmarks'. The code snippet only shows that 'favCountParams' is being added to 'interestedInCandidates.size'. However, it does not provide any context about what 'interestedInCandidates' represents or whether it includes 'Likes' and 'Bookmarks'. To determine if 'favCountParams' represents the total of 'Likes' and 'Bookmarks', more context about these variables and their usage in the codebase would be required.
#
# -> **Question**: What are the major negative modifiers that lower your linear ranking parameters?
#
# **Answer**:   The major negative modifiers that affect the linear ranking parameters include:
# * numMutualFollowPath: The smaller the number of mutual follow paths between the user and the candidate, the lower the candidate's ranking.
# * numLowTweepcredFollowPath: The smaller the number of mutual low TweepCred paths between the user and the candidate, the lower the candidate's ranking.
# * hasForwardEmailPath, hasReverseEmailPath, hasForwardPhonebookPath, and hasReversePhonebookPath: If there is no third user x in the user's email book, phonebook, reverse email book, or reverse phonebook that connects the user -> x -> candidate, respectively, the candidate's ranking is lowered.
# * The absence of any positive features, such as realGraphWeight, isForwardEmail, isReverseEmail, isForwardPhonebook, or isReversePhonebook, will also negatively impact the candidate's ranking.
#
# -> **Question**: How do you get assigned to SimClusters?
#
# **Answer**:  The assignment of a user to a SimCluster is determined by the UserSimilarityEngine, which computes similarity scores between users based on their tweet and follower/following relationships. The engine uses various algorithms, such as SimClustersANN or TweetBasedTwHINANN, to calculate these scores. The user is then assigned to the SimCluster with the highest average similarity score to the other users in that cluster.
#
# -> **Question**: What is needed to migrate from one SimClusters to another SimClusters?
#
# **Answer**:   To migrate a user from one SimCluster to another SimCluster, you need to follow these steps:
#
# 1. Identify the user's current SimCluster by looking up their internal ID in the SimClusters store.
# 2. Determine the new SimCluster to which you want to migrate the user. This could be based on various factors such as improved performance, better accuracy, or a new feature.
# 3. Update the SimClusters store with the new SimCluster information for the user.
# 4. Refresh the user's Sims cache by updating the CachedSimsStore and CachedDBV2SimsStore.
# 5. If the migration involves a change in the similarity engine, update the corresponding store (e.g., SimClustersANNStore, TweetBasedUserTweetGraphStore, etc.) with the new engine information.
# 6. Update the stats counters to reflect the migration.
#
# Please note that the actual implementation of these steps may vary depending on the specific SimCluster and its associated stores and services. Additionally, it's important to consider any potential impact on the user experience or performance during the migration process.
#
# -> **Question**: How much do I get boosted within my cluster?
#
# **Answer**:  The boost factor within a SimCluster refers to the score multiplier applied to candidate tweets that belong to the same SimCluster as the target tweet. The exact value of the boost factor depends on the specific configuration of the SimClusters Similarity Engine, including the similarity threshold and the number of clusters. The goal of using boost factors is to prioritize candidate tweets that are more similar to the target tweet and therefore more likely to be relevant to the query.
#
# -> **Question**: How does Heavy ranker work. what are it’s main inputs?
#
# **Answer**:  The main inputs for the Heavy ranker algorithm are the DataRecords, which are constructed for each <user, candidate> pair and contain the ML features. These DataRecords are then sent to a separate ML prediction service, which houses the ML model trained offline. The ML model returns a prediction score, representing the probability that a user will follow and engage with the candidate, which is used to rank the candidates.
#
# -> **Question**: How can one influence Heavy ranker?
#
# **Answer**:  The heavy ranker algorithm is not explicitly shown in the given code snippet. However, based on the context provided, it can be inferred that the heavy filtering is applied in the `validateCandidates` step. This step determines the eligibility of the candidates and will only be applied to candidates that are expected to return. The actual implementation of the heavy ranker algorithm is not provided in the code snippet. Therefore, to change the ranking order of the candidates in the heavy ranker algorithm, one would need to modify or extend the `validateCandidates` method or implement a new method to replace it.
#
# Additional context or information about the heavy ranker algorithm, such as the specific ranking algorithm used, the factors considered in the ranking, and the data sources used, would be necessary to provide a more accurate answer.
#
# -> **Question**: why threads and long tweets do so well on the platform?
#
# **Answer**:
#
# Threads and long tweets perform well on the Twitter platform for several reasons:
#
# 1. Threads allow for a more conversational experience: Threads enable users to reply to each other in a more organized and readable way. This makes it easier for users to follow conversations and engage with each other.
# 2. Long tweets provide more context: Long tweets allow users to express their thoughts and ideas more fully. This can lead to more meaningful and engaging conversations.
# 3. Twitter's infrastructure is optimized for handling threads and long tweets: Twitter's servers and algorithms are designed to efficiently process and display threads and long tweets. This ensures that users can access and engage with this content in a seamless and performant way.
# 4. Twitter uses efficient data structures and algorithms for handling threads and long tweets: Twitter uses data structures like trees and graphs to efficiently manage the relationships between tweets in a thread. They also use algorithms like graph traversal and indexing to quickly retrieve and display threaded content.
# 5. Twitter's machine learning models are optimized for handling threads and long tweets: Twitter's machine learning models are trained to understand the context and meaning of threads and long tweets. This allows them to provide more accurate and relevant recommendations and suggestions based on this content.
#
# Overall, threads and long tweets are an important part of the Twitter experience, and Twitter's infrastructure and algorithms are optimized to handle them efficiently and effectively.
#
# -> **Question**: Are thread and long tweet creators building a following that reacts to only threads?
#
# **Answer**:  To answer this question, you would need to analyze the user signals related to thread and long tweet engagement, such as retweets, quote tweets, replies, and video watches. By examining the distribution of these signals among the followers of thread and long tweet creators, you could determine if there is a significant correlation between the two. You could also consider using machine learning techniques, such as clustering or regression, to identify patterns in the data and quantify the relationship. However, without access to the specific user data and signals, it is impossible to provide a definitive answer.
#
# -> **Question**: Do you need to follow different strategies to get most followers vs to get most likes and bookmarks per tweet?
#
# **Answer**:  To maximize the number of followers, effective strategies include engaging with relevant and popular content, using targeted hashtags, and consistently posting high-quality and interesting tweets. Additionally, utilizing follow recommendations and collaborating with other users or communities can help expand your reach.
#
# To maximize the number of likes and bookmarks per tweet, focus on creating content that resonates with your audience. This can include using attention-grabbing headlines, providing value or insight, and incorporating multimedia elements such as images or videos. Timing your tweets to reach your audience during peak engagement hours can also help increase engagement. Finally, engaging with your audience by responding to comments and interacting with other users can also lead to more likes and bookmarks.
#
# -> **Question**: Content meta data and how it impacts virality (e.g. ALT in images).
#
# **Answer**:  Content metadata, such as ALT text in images, can be used as features in machine learning models to predict the virality of tweets. These features can be extracted from the tweet data using various libraries and tools, such as OpenCV for image processing. The extracted features can then be used in models like SimClusters or TwHIN to learn embeddings that represent the content and its semantic meaning. These embeddings can be used as input to downstream models, such as product mixer, to generate recommendations for users based on their interests and past interactions. Therefore, having accurate and descriptive metadata can improve the quality of the recommendations and potentially increase the virality of tweets.
#
# -> **Question**: What are some unexpected fingerprints for spam factors?
#
# **Answer**:  Some unexpected sources of spam factors in tweets could include tweets with a large number of retweets or quote tweets, tweets with a high number of replies, tweets with a lot of hashtags or mentions, tweets with suspicious URLs, or tweets with a high frequency of certain keywords or phrases. These factors, while not necessarily indicative of spam on their own, can be used in conjunction with other signals to help identify potentially spammy content.
#
# -> **Question**: Is there any difference between company verified checkmarks and blue verified individual checkmarks?
#
# **Answer**:  A company verified checkmark is a badge that appears next to a Twitter account that has been confirmed as an authentic representation of a company or organization. A blue verified individual checkmark, on the other hand, is a badge that appears next to an individual's Twitter account that has been confirmed as authentic and notable. Both types of checkmarks help users identify the authenticity and credibility of Twitter accounts.
