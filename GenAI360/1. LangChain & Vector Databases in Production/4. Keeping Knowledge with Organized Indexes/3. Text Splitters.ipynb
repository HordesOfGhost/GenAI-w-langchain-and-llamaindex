# %%
from dotenv import load_dotenv

load_dotenv('../../.env')
# Out:
# True

# %% [markdown]
# # Character Text Splitters

# %%
from langchain.document_loaders import PyPDFLoader
loader = PyPDFLoader("Linux.pdf")
pages = loader.load_and_split()

# %%
from langchain.text_splitter import CharacterTextSplitter

text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=20)
texts = text_splitter.split_documents(pages)

print(texts[0])

print (f"You have {len(texts)} documents")
print ("Preview:")
print (texts[0].page_content)
# Out:
# page_content='THE ONE     PAGE LINUX MANUALA summary of useful Linux commands\nVersion 3.0 May 1999 squadron@powerup.com.au\nStarting & Stopping\nshutdown -h now Shutdown the system now and do not\nreboot\nhalt Stop all processes - same as above\nshutdown -r 5 Shutdown the system in 5 minutes and\nreboot\nshutdown -r now Shutdown the system now and reboot\nreboot Stop all processes and then reboot - same\nas above\nstartx Start the X system\nAccessing & mounting file systems\nmount -t iso9660 /dev/cdrom\n/mnt/cdromMount the device cdrom\nand call it cdrom under the\n/mnt directory\nmount -t msdos /dev/hdd\n/mnt/ddriveMount hard disk “d” as a\nmsdos file system and call\nit ddrive under the /mnt\ndirectory\nmount -t vfat /dev/hda1\n/mnt/cdriveMount hard disk “a” as a\nVFAT file system and call it\ncdrive under the /mnt\ndirectory\numount /mnt/cdrom Unmount the cdrom\nFinding files and text within files\nfind / -name  fname Starting with the root directory, look\nfor the file called fname\nfind / -name ”*fname* ” Starting with the root directory, look\nfor the file containing the string fname\nlocate missingfilename Find a file called missingfilename\nusing the locate command - this\nassumes you have already used the\ncommand updatedb (see next)\nupdatedb Create or update the database of files\non all file systems attached to the linux\nroot directory\nwhich missingfilename Show the subdirectory containing the\nexecutable file  called missingfilename\ngrep textstringtofind\n/dirStarting with the directory called dir ,\nlook for and list all files containing\ntextstringtofind\nThe X Window System\nxvidtune Run the X graphics tuning utility\nXF86Setup Run the X configuration menu with\nautomatic probing of graphics cards\nXconfigurator Run another X configuration menu with\nautomatic probing of graphics cards\nxf86config Run a text based X configuration menu\nMoving, copying, deleting & viewing files\nls -l List files in current directory using\nlong format\nls -F List files in current directory and\nindicate the file type\nls -laC List all files in current directory in\nlong format and display in columnsrm name Remove a file or directory called\nname\nrm -rf name Kill off an entire directory and all it’s\nincludes files and subdirectories\ncp filename\n/home/dirnameCopy the file called filename to the\n/home/dirname directory\nmv filename\n/home/dirnameMove the file called filename to the\n/home/dirname directory\ncat filetoview Display the file called filetoview\nman -k keyword Display man pages containing\nkeyword\nmore filetoview Display the file called filetoview one\npage at a time, proceed to next page\nusing the spacebar\nhead filetoview Display the first 10 lines of the file\ncalled filetoview\nhead -20 filetoview Display the first 20 lines of the file\ncalled filetoview\ntail filetoview Display the last 10 lines of the file\ncalled filetoview\ntail -20 filetoview Display the last 20 lines of the file\ncalled filetoview\nInstalling software for Linux\nrpm -ihv name.rpm Install the rpm package called name\nrpm -Uhv name.rpm Upgrade the rpm package called\nname\nrpm -e package Delete the rpm package called\npackage\nrpm -l package List the files in the package called\npackage\nrpm -ql package List the files and state the installed\nversion of the package called\npackage\nrpm -i --force package Reinstall the rpm package called\nname having deleted parts of it (not\ndeleting using rpm -e)\ntar -zxvf archive.tar.gz or\ntar -zxvf archive.tgzDecompress the files contained in\nthe zipped and tarred archive called\narchive\n./configure Execute the script preparing the\ninstalled files for compiling\nUser Administration\nadduser accountname Create a new user call accountname\npasswd accountname Give accountname a new password\nsu Log in as superuser from current login\nexit Stop being superuser and revert to\nnormal user\nLittle known tips and tricks\nifconfig List ip addresses for all devices on\nthe machine\napropos subject List  ...
# You have 2 documents
# Preview:
# THE ONE     PAGE LINUX MANUALA summary of useful Linux commands
# Version 3.0 May 1999 squadron@powerup.com.au
# Starting & Stopping
# shutdown -h now Shutdown the system now and do not
# reboot
# halt Stop all processes - same as above
# shutdown -r 5 Shutdown the system in 5 minutes and
# reboot
# shutdown -r now Shutdown the system now and reboot
# reboot Stop all processes and then reboot - same
# as above
# startx Start the X system
# Accessing & mounting file systems
# mount -t iso9660 /dev/cdrom
# /mnt/cdromMount the device cdrom
# and call it cdrom under the
# /mnt directory
# mount -t msdos /dev/hdd
# /mnt/ddriveMount hard disk “d” as a
# msdos file system and call
# it ddrive under the /mnt
# directory
# mount -t vfat /dev/hda1
# /mnt/cdriveMount hard disk “a” as a
# VFAT file system and call it
# cdrive under the /mnt
# directory
# umount /mnt/cdrom Unmount the cdrom
# Finding files and text within files
# find / -name  fname Starting with the root directory, look
# for the file called fname
# find / -name ”*fname* ” Starting with the root directory, look
# for the file containing the string fname
# locate missingfilename Find a file called missingfilename
# using the locate command - this
# assumes you have already used the
# command updatedb (see next)
# updatedb Create or update the database of files
# on all file systems attached to the linux
# root directory
# which missingfilename Show the subdirectory containing the
# executable file  called missingfilename
# grep textstringtofind
# /dirStarting with the directory called dir ,
# look for and list all files containing
# textstringtofind
# The X Window System
# xvidtune Run the X graphics tuning utility
# XF86Setup Run the X configuration menu with
# automatic probing of graphics cards
# Xconfigurator Run another X configuration menu with
# automatic probing of graphics cards
# xf86config Run a text based X configuration menu
# Moving, copying, deleting & viewing files
# ls -l List files in current directory using
# long format
# ls -F List files in current directory and
# indicate the file type
# ls -laC List all files in current directory in
# long format and display in columnsrm name Remove a file or directory called
# name
# rm -rf name Kill off an entire directory and all it’s
# includes files and subdirectories
# cp filename
# /home/dirnameCopy the file called filename to the
# /home/dirname directory
# mv filename
# /home/dirnameMove the file called filename to the
# /home/dirname directory
# cat filetoview Display the file called filetoview
# man -k keyword Display man pages containing
# keyword
# more filetoview Display the file called filetoview one
# page at a time, proceed to next page
# using the spacebar
# head filetoview Display the first 10 lines of the file
# called filetoview
# head -20 filetoview Display the first 20 lines of the file
# called filetoview
# tail filetoview Display the last 10 lines of the file
# called filetoview
# tail -20 filetoview Display the last 20 lines of the file
# called filetoview
# Installing software for Linux
# rpm -ihv name.rpm Install the rpm package called name
# rpm -Uhv name.rpm Upgrade the rpm package called
# name
# rpm -e package Delete the rpm package called
# package
# rpm -l package List the files in the package called
# package
# rpm -ql package List the files and state the installed
# version of the package called
# package
# rpm -i --force package Reinstall the rpm package called
# name having deleted parts of it (not
# deleting using rpm -e)
# tar -zxvf archive.tar.gz or
# tar -zxvf archive.tgzDecompress the files contained in
# the zipped and tarred archive called
# archive
# ./configure Execute the script preparing the
# installed files for compiling
# User Administration
# adduser accountname Create a new user call accountname
# passwd accountname Give accountname a new password
# su Log in as superuser from current login
# exit Stop being superuser and revert to
# normal user
# Little known tips and tricks
# ifconfig List ip addresses for all devices on
# the machine
# apropos subject List manual pages for subject
# usermount Executes graphical application for
# mounting and unmounting file
# systems

# %% [markdown]
# # Recursive Character Text Splitter

# %%
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

loader = PyPDFLoader("Linux.pdf")
pages = loader.load_and_split()

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=50,
    chunk_overlap=10,
    length_function=len,
)

docs = text_splitter.split_documents(pages)
for doc in docs:
    print(doc)
# Out:
# page_content='THE ONE     PAGE LINUX MANUALA summary of useful' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='of useful Linux commands' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='Version 3.0 May 1999 squadron@powerup.com.au' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='Starting & Stopping' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='shutdown -h now Shutdown the system now and do' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='and do not' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='reboot\nhalt Stop all processes - same as above' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='shutdown -r 5 Shutdown the system in 5 minutes' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='5 minutes and' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='reboot' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='shutdown -r now Shutdown the system now and' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='now and reboot' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='reboot Stop all processes and then reboot - same' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='as above\nstartx Start the X system' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='Accessing & mounting file systems' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='mount -t iso9660 /dev/cdrom' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='/mnt/cdromMount the device cdrom' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='and call it cdrom under the\n/mnt directory' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='mount -t msdos /dev/hdd' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='/mnt/ddriveMount hard disk “d” as a' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='msdos file system and call' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='it ddrive under the /mnt\ndirectory' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='directory\nmount -t vfat /dev/hda1' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='/mnt/cdriveMount hard disk “a” as a' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='VFAT file system and call it' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='cdrive under the /mnt\ndirectory' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='directory\numount /mnt/cdrom Unmount the cdrom' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='Finding files and text within files' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='find / -name  fname Starting with the root' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='the root directory, look' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='for the file called fname' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='find / -name ”*fname* ” Starting with the root' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='the root directory, look' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='for the file containing the string fname' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='locate missingfilename Find a file called' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='called missingfilename' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='using the locate command - this' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='assumes you have already used the' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='command updatedb (see next)' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='updatedb Create or update the database of files' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='on all file systems attached to the linux' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='root directory' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='which missingfilename Show the subdirectory' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='containing the' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='executable file  called missingfilename' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='grep textstringtofind' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='/dirStarting with the directory called dir ,' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='look for and list all files containing' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='textstringtofind\nThe X Window System' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='xvidtune Run the X graphics tuning utility' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='XF86Setup Run the X configuration menu with' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='automatic probing of graphics cards' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='Xconfigurator Run another X configuration menu' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='menu with' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='automatic probing of graphics cards' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='xf86config Run a text based X configuration menu' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='Moving, copying, deleting & viewing files' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='ls -l List files in current directory using' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='long format' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='ls -F List files in current directory and' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='indicate the file type' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='ls -laC List all files in current directory in' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='long format and display in columnsrm name Remove' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='Remove a file or directory called' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='name' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='rm -rf name Kill off an entire directory and all' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='and all it’s' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='includes files and subdirectories\ncp filename' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='/home/dirnameCopy the file called filename to the' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='/home/dirname directory\nmv filename' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='/home/dirnameMove the file called filename to the' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='/home/dirname directory' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='cat filetoview Display the file called filetoview' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='man -k keyword Display man pages containing' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='keyword' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='more filetoview Display the file called' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='called filetoview one' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='page at a time, proceed to next page' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='using the spacebar' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='head filetoview Display the first 10 lines of the' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='of the file' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='called filetoview' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='head -20 filetoview Display the first 20 lines of' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='lines of the file' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='called filetoview' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='tail filetoview Display the last 10 lines of the' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='of the file' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='called filetoview' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='tail -20 filetoview Display the last 20 lines of' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='lines of the file' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='called filetoview\nInstalling software for Linux' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='rpm -ihv name.rpm Install the rpm package called' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='called name' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='rpm -Uhv name.rpm Upgrade the rpm package called' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='name\nrpm -e package Delete the rpm package called' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='package' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='rpm -l package List the files in the package' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='package called' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='package' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='rpm -ql package List the files and state the' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='state the installed' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='version of the package called\npackage' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='rpm -i --force package Reinstall the rpm package' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='package called' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='name having deleted parts of it (not' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='deleting using rpm -e)' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='tar -zxvf archive.tar.gz or' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='tar -zxvf archive.tgzDecompress the files' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='the files contained in' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='the zipped and tarred archive called\narchive' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='./configure Execute the script preparing the' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='installed files for compiling\nUser Administration' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='adduser accountname Create a new user call' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='user call accountname' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='passwd accountname Give accountname a new' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='a new password' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='su Log in as superuser from current login' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='exit Stop being superuser and revert to' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='normal user\nLittle known tips and tricks' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='ifconfig List ip addresses for all devices on' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='the machine' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='apropos subject List manual pages for subject' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='usermount Executes graphical application for' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='mounting and unmounting file\nsystems' metadata={'source': 'Linux.pdf', 'page': 0}
# page_content='/sbin/e2fsck hda5 Execute the filesystem check' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='check utility' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='on partition hda5' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='fdformat /dev/fd0H1440 Format the floppy disk in' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='disk in device fd0' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='tar -cMf /dev/fd0 Backup the contents of the' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='of the current' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='directory and subdirectories to' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='multiple floppy disks' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='tail -f /var/log/messages Display the last 10' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='last 10 lines of the system' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='log.' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='cat /var/log/dmesg Display the file containing' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='the boot' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='time messages - useful for locating' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='problems. Alternatively, use the\ndmesg  command.' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='* wildcard - represents everything. eg.' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='cp from/* to  will copy all files in the' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='from directory to the to directory' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='? Single character wildcard. eg.' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='cp config.? /configs will copy all files' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='beginning with the name config. in' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='the current directory to the directory' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='named configs.' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='[xyz] Choice of character wildcards. eg.' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='ls [xyz]* will list all files in the current' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='directory starting with the letter x, y,\nor z.' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='linux single At the lilo prompt, start in single' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='in single user' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='mode. This is useful if you have' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='forgotten your password. Boot in' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='single user mode, then run the\npasswd  command.' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='ps List current processes' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='kill 123 Kill a specific process eg. kill 123' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='Configuration files and what they do' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='/etc/profile System wide environment variables' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='variables for' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='all users.' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='/etc/fstab List of devices and their associated' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='mount' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='points. Edit this file to add cdroms, DOS' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='partitions and floppy drives at startup.' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='/etc/motd Message of the day broadcast to all' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='to all users' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='at login.' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='etc/rc.d/rc.local Bash script that is executed at' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='at the end of' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='login process. Similar to autoexec.bat in\nDOS.' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='/etc/HOSTNAME Conatins full hostname including' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='including domain.' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='/etc/cron.* There are 4 directories that' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='that automatically' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='execute all scripts within the directory at' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='intervals of hour, day, week or month.' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='/etc/hosts A list of all know host names and IP' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='addresses on the machine.' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='/etc/httpd/conf Paramters for the Apache web' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='web server' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='/etc/inittab Specifies the run level that the' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='that the machine' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='should boot into.' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='/etc/resolv.conf Defines IP addresses of DNS' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='of DNS servers.' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='/etc/smb.conf Config file for the SAMBA server.' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='server. Allows' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='file and print sharing with Microsoft\nclients.' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='clients.\n/etc/X11/XF86Confi' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='gConfig file for X -Windows.' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='~/.xinitrc Defines the windows manager loaded by' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='X. ~ refers to user’s home directory.File' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='permissions' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='If the command ls -l is given, a long list of' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='list of file names is' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='displayed. The first column in this list details' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='details the permissions' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='applying to the file. If a permission is missing' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='missing for a owner,' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='group of other, it is represented by - eg.  drwxr' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='drwxr -x—x' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='Read = 4\nWrite = 2' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='Execute = 1File permissions are altered by giving' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='by giving the' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='chmod command and the appropriate' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='octal code for each user type. eg' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='chmod 7 6 4 filename will make the file' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='called filename R+W+X for the owner,' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='R+W for the group and R for others.' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='chmod 7 5 5 Full permission for the owner, read' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='read and' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='execute access for the group and others.' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='chmod +x filename Make the file called filename' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='filename executable' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='to all users.\nX Shortcuts - (mainly for Redhat)' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='Control|Alt  + or - Increase or decrease the' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='the screen' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='resolution. eg. from 640x480 to\n800x600' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='Alt | escape Display list of active windows' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='Shift|Control F8 Resize the selected window' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='Right click on desktop\nbackgroundDisplay menu' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='Shift|Control Altr Refresh the screen' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='Shift|Control Altx Start an xterm session' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='Printing' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='/etc/rc.d/init.d/lpd start Start the print daemon' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='/etc/rc.d/init.d/lpd stop Stop the print daemon' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='/etc/rc.d/init.d/lpd' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='statusDisplay status of the print daemon' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='lpq Display jobs in print queue' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='lprm Remove jobs from queue\nlpr Print a file' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='lpc Printer control tool' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='man subject | lpr Print the manual page called' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='called subject' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='as plain text' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='man -t subject | lpr Print the manual page called' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='called subject' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='as Postscript output' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='printtool Start X printer setup' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='setup interface~/.Xdefaults Define configuration' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='for some X -' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='applications. ~ refers to user’s home\ndirectory.' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='Get your own Official Linux Pocket Protector -' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='- includes' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='handy command summary. Visit:' metadata={'source': 'Linux.pdf', 'page': 1}
# page_content='www.powerup.com.au/~squadron' metadata={'source': 'Linux.pdf', 'page': 1}

# %% [markdown]
# # NLTK text Splitter

# %%
import nltk 
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Ghost\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from langchain.text_splitter import NLTKTextSplitter

# Load a long document
with open('llm.txt', encoding= 'unicode_escape') as f:
    sample_text = f.read()

text_splitter = NLTKTextSplitter(chunk_size=500)
texts = text_splitter.split_text(sample_text)
print(texts)
# Out:
# ["AI-generated content is becoming increasingly sophisticated, making it challenging to distinguish between genuine and computer-generated text.Fraud emails and \nFake news are becoming everyday's story.My project aims to tackle this issue by leveraging the power of BERT (Bidirectional Encoder Representations from Transformers) to identify and \nflag AI-generated text segments.\n\nThis would allow the AI to advance at much faster pace but not at the expense of human security and fundamental integrity.", 'This would allow the AI to advance at much faster pace but not at the expense of human security and fundamental integrity.\n\nThe solution follows a comprehensive approach to detect AI-generated texts ð\x9f\x92¡\n\nData Preprocessing: We clean and preprocess the textual data, removing the noise, stop words, puntuations and non-alphabatical words.', 'This was done using Bert-Preprocess\n\nAdditional Datasets I collected various datasets which were hosted by various competitions like the one in analysis, and concatinated them and used the collective data to train my model.\n\nThis increased my training instances form 1378 to around 50k.\n\nAllowing my model to train on a large set of varrying data allowing effective feature identification and implementation.', 'This increased my training instances form 1378 to around 50k.\n\nAllowing my model to train on a large set of varrying data allowing effective feature identification and implementation.\n\nModel Training: Using a BERT-based sequence classification model, we train the system to distinguish between genuine and AI-generated text with a high degree of accuracy.', 'Model Training: Using a BERT-based sequence classification model, we train the system to distinguish between genuine and AI-generated text with a high degree of accuracy.\n\nHere I used bert-base-uncase, one may also use bert-large-cased but that may significantly increase the training time as it has 24 encoder layers instead of 12 in the case of base version, which would reduce the submission score.', 'Predictions: Once trained, the model generates predictions for test data, highlighting potential AI-generated content segments.\n\nThe predictions have been done upon the test data.\n\nResult Analysis: The results are then saved in a CSV file, which was then submitted in the contest.']

# %% [markdown]
# # SpacyTextSplitter

# %%
from langchain.text_splitter import SpacyTextSplitter

# Load a long document
with open('llm.txt', encoding= 'unicode_escape') as f:
    sample_text = f.read()

# Instantiate the SpacyTextSplitter with the desired chunk size
text_splitter = SpacyTextSplitter(chunk_size=500, chunk_overlap=20)

# Split the text using SpacyTextSplitter
texts = text_splitter.split_text(sample_text)

# Print the first chunk
print(texts[0])

# %% [markdown]
# # MarkdownTextSplitter

# %%
from langchain.text_splitter import MarkdownTextSplitter

markdown_text = """
# 

# Welcome to My Blog!

## Introduction
Hello everyone! My name is **John Doe** and I am a _software developer_. I specialize in Python, Java, and JavaScript.

Here's a list of my favorite programming languages:

1. Python
2. JavaScript
3. Java

You can check out some of my projects on [GitHub](https://github.com).

## About this Blog
In this blog, I will share my journey as a software developer. I'll post tutorials, my thoughts on the latest technology trends, and occasional book reviews.

Here's a small piece of Python code to say hello:

\``` python
def say_hello(name):
    print(f"Hello, {name}!")

say_hello("John")
\```

Stay tuned for more updates!

## Contact Me
Feel free to reach out to me on [Twitter](https://twitter.com) or send me an email at johndoe@email.com.

"""

markdown_splitter = MarkdownTextSplitter(chunk_size=100, chunk_overlap=0)
docs = markdown_splitter.create_documents([markdown_text])

print(docs)
# Out:
# [Document(page_content='# \n\n# Welcome to My Blog!', metadata={}), Document(page_content='## Introduction', metadata={}), Document(page_content='Hello everyone! My name is **John Doe** and I am a _software developer_. I specialize in Python,', metadata={}), Document(page_content='Java, and JavaScript.', metadata={}), Document(page_content="Here's a list of my favorite programming languages:\n\n1. Python\n2. JavaScript\n3. Java", metadata={}), Document(page_content='You can check out some of my projects on [GitHub](https://github.com).', metadata={}), Document(page_content='## About this Blog', metadata={}), Document(page_content="In this blog, I will share my journey as a software developer. I'll post tutorials, my thoughts on", metadata={}), Document(page_content='the latest technology trends, and occasional book reviews.', metadata={}), Document(page_content="Here's a small piece of Python code to say hello:", metadata={}), Document(page_content='\\``` python\ndef say_hello(name):\n    print(f"Hello, {name}!")\n\nsay_hello("John")\n\\', metadata={}), Document(page_content='```\n\nStay tuned for more updates!', metadata={}), Document(page_content='## Contact Me', metadata={}), Document(page_content='Feel free to reach out to me on [Twitter](https://twitter.com) or send me an email at', metadata={}), Document(page_content='johndoe@email.com.', metadata={})]

# %% [markdown]
# # TokenTextSplitter

# %%
from langchain.text_splitter import TokenTextSplitter

# Load a long document
with open('llm.txt', encoding= 'unicode_escape') as f:
    sample_text = f.read()

# Initialize the TokenTextSplitter with desired chunk size and overlap
text_splitter = TokenTextSplitter(chunk_size=100, chunk_overlap=50)

# Split into smaller chunks
texts = text_splitter.split_text(sample_text)
print(texts[0])
# Out:
# AI-generated content is becoming increasingly sophisticated, making it challenging to distinguish between genuine and computer-generated text.Fraud emails and
# Fake news are becoming everyday's story.My project aims to tackle this issue by leveraging the power of BERT (Bidirectional Encoder Representations from Transformers) to identify and
# flag AI-generated text segments. This would allow the AI to advance at much faster pace but not at the expense of human security and fundamental integrity.
#
# The
