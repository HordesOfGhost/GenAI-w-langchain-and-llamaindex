# %%
from dotenv import load_dotenv

load_dotenv('../../.env')
# Out:
# True

# %%
import os
import textwrap
from dotenv import load_dotenv
from llama_index.core import download_loader
from llama_hub.github_repo import GithubRepositoryReader, GithubClient
from llama_index import VectorStoreIndex
from llama_index.vector_stores.deeplake import DeepLakeVectorStore
from llama_index.storage.storage_context import StorageContext
from llama_index.llms.huggingface import HuggingFaceInferenceAPI
from llama_index.core import set_global_tokenizer
from transformers import AutoTokenizer
import re

# Load environment variables
load_dotenv()

# Fetch and set API keys
hugging_face_token = os.getenv("HUGGINGFACEHUB_API_TOKEN")
active_loop_token = os.getenv("ACTIVELOOP_TOKEN")
dataset_path = os.getenv("DATASET_PATH")


def parse_github_url(url):
    pattern = r"https://github\.com/([^/]+)/([^/]+)"
    match = re.match(pattern, url)
    return match.groups() if match else (None, None)


def validate_owner_repo(owner, repo):
    return bool(owner) and bool(repo)


def initialize_github_client():
    github_token = os.getenv("GITHUB_TOKEN")
    return GithubClient(github_token)


def main():
    # Check for OpenAI API key
    hugging_face_token = os.getenv("HUGGINGFACEHUB_API_TOKEN")
    if not hugging_face_token:
        raise EnvironmentError("OpenAI API key not found in environment variables")

    # Check for GitHub Token
    github_token = os.getenv("GITHUB_TOKEN")
    if not github_token:
        raise EnvironmentError("GitHub token not found in environment variables")

    # Check for Activeloop Token
    active_loop_token = os.getenv("ACTIVELOOP_TOKEN")
    if not active_loop_token:
        raise EnvironmentError("Activeloop token not found in environment variables")

    github_client = initialize_github_client()
    download_loader("GithubRepositoryReader")

    github_url = input("Please enter the GitHub repository URL: ")
    owner, repo = parse_github_url(github_url)

    while True:
        owner, repo = parse_github_url(github_url)
        if validate_owner_repo(owner, repo):
            loader = GithubRepositoryReader(
                github_client,
                owner=owner,
                repo=repo,
                filter_file_extensions=(
                    [".py", ".js", ".ts", ".md",".html",".json",".txt"],
                    # GithubRepositoryReader.FilterType.INCLUDE,
                ),
                verbose=False,
                concurrent_requests=5,
            )
            print(f"Loading {repo} repository by {owner}")
            docs = loader.load_data(branch="main")
            print("Documents uploaded:")
            for doc in docs:
                print(doc.metadata)
            break  # Exit the loop once the valid URL is processed
        else:
            print("Invalid GitHub URL. Please try again.")
            github_url = input("Please enter the GitHub repository URL: ")

    print("Uploading to vector store...")

    # ====== Create vector store and upload data ======

    vector_store = DeepLakeVectorStore(
        dataset_path=dataset_path,
        overwrite=True,
        runtime={"tensor_db": True},
    )
    set_global_tokenizer(
        AutoTokenizer.from_pretrained("HuggingFaceH4/zephyr-7b-alpha").encode
    )
    llm = HuggingFaceInferenceAPI(
        model_name='mistralai/Mistral-7B-Instruct-v0.2',
        generate_kwargs={'temperature':0.5,"max_length": 64,"max_new_tokens":512}
    )

    storage_context = StorageContext.from_defaults(vector_store=vector_store)
    index = VectorStoreIndex.from_documents(docs, storage_context=storage_context,embed_model='local')
    query_engine = index.as_query_engine(llm = llm)

    # Include a simple question to test.
    intro_question = "What is the repository about?"
    print(f"Test question: {intro_question}")
    print("=" * 50)
    answer = query_engine.query(intro_question)

    print(f"Answer: {textwrap.fill(str(answer), 100)} \n")
    while True:
        user_question = input("Please enter your question (or type 'exit' to quit): ")
        if user_question.lower() == "exit":
            print("Exiting, thanks for chatting!")
            break

        print(f"Your question: {user_question}")
        print("=" * 50)

        answer = query_engine.query(user_question)
        print(f"Answer: {textwrap.fill(str(answer), 100)} \n")


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 4
#       2 import textwrap
#       3 from dotenv import load_dotenv
# ----> 4 from llama_index.core import download_loader
#       5 from llama_hub.github_repo import GithubRepositoryReader, GithubClient
#       6 from llama_index import VectorStoreIndex
#
# File c:\Users\Ghost\anaconda3\envs\genai360\lib\site-packages\llama_index\core\__init__.py:18
#      14 from llama_index.core.embeddings.mock_embed_model import MockEmbedding
#      16 # indices
#      17 # loading
# ---> 18 from llama_index.core.indices import (
#      19     ComposableGraph,
#      20     DocumentSummaryIndex,
#      21     GPTDocumentSummaryIndex,
#      22     GPTKeywordTableIndex,
#      23     GPTListIndex,
#      24     GPTRAKEKeywordTableIndex,
#      25     GPTSimpleKeywordTableIndex,
#      26     GPTTreeIndex,
#      27     GPTVectorStoreIndex,
#      28     KeywordTableIndex,
#      29     KnowledgeGraphIndex,
#      30     ListIndex,
#      31     RAKEKeywordTableIndex,
#      32     SimpleKeywordTableIndex,
#      33     SummaryIndex,
#      34     TreeIndex,
#      35     VectorStoreIndex,
#      36     load_graph_from_storage,
#      37     load_index_from_storage,
#      38     load_indices_from_storage,
#      39 )
#      41 # structured
#      42 from llama_index.core.indices.common.struct_store.base import (
#      43     SQLDocumentContextBuilder,
#      44 )
#
# File c:\Users\Ghost\anaconda3\envs\genai360\lib\site-packages\llama_index\core\indices\__init__.py:4
#       1 """LlamaIndex data structures."""
#       3 # indices
# ----> 4 from llama_index.core.indices.composability.graph import ComposableGraph
#       5 from llama_index.core.indices.document_summary import (
#       6     DocumentSummaryIndex,
#       7     GPTDocumentSummaryIndex,
#       8 )
#       9 from llama_index.core.indices.document_summary.base import DocumentSummaryIndex
#
# File c:\Users\Ghost\anaconda3\envs\genai360\lib\site-packages\llama_index\core\indices\composability\__init__.py:4
#       1 """This module contains all classes used for composing graphs over indices."""
# ----> 4 from llama_index.core.indices.composability.graph import ComposableGraph
#       6 __all__ = ["ComposableGraph"]
#
# File c:\Users\Ghost\anaconda3\envs\genai360\lib\site-packages\llama_index\core\indices\composability\graph.py:7
#       5 from llama_index.core.base.base_query_engine import BaseQueryEngine
#       6 from llama_index.core.data_structs.data_structs import IndexStruct
# ----> 7 from llama_index.core.indices.base import BaseIndex
#       8 from llama_index.core.schema import (
#       9     IndexNode,
#      10     NodeRelationship,
#      11     ObjectType,
#      12     RelatedNodeInfo,
#      13 )
#      14 from llama_index.core.service_context import ServiceContext
#
# File c:\Users\Ghost\anaconda3\envs\genai360\lib\site-packages\llama_index\core\indices\base.py:12
#      10 from llama_index.core.chat_engine.types import BaseChatEngine, ChatMode
#      11 from llama_index.core.data_structs.data_structs import IndexStruct
# ---> 12 from llama_index.core.ingestion import run_transformations
#      13 from llama_index.core.llms.utils import LLMType, resolve_llm
#      14 from llama_index.core.schema import BaseNode, Document, IndexNode, TransformComponent
#
# File c:\Users\Ghost\anaconda3\envs\genai360\lib\site-packages\llama_index\core\ingestion\__init__.py:2
#       1 from llama_index.core.ingestion.cache import IngestionCache
# ----> 2 from llama_index.core.ingestion.pipeline import (
#       3     DocstoreStrategy,
#       4     IngestionPipeline,
#       5     arun_transformations,
#       6     run_transformations,
#       7 )
#       9 __all__ = [
#      10     "DocstoreStrategy",
#      11     "IngestionCache",
#    (...)
#      14     "arun_transformations",
#      15 ]
#
# File c:\Users\Ghost\anaconda3\envs\genai360\lib\site-packages\llama_index\core\ingestion\pipeline.py:31
#      24 from llama_index.core.constants import (
#      25     DEFAULT_APP_URL,
#      26     DEFAULT_BASE_URL,
#      27     DEFAULT_PIPELINE_NAME,
#      28     DEFAULT_PROJECT_NAME,
#      29 )
#      30 from llama_index.core.bridge.pydantic import BaseModel, Field
# ---> 31 from llama_index.core.ingestion.api_utils import get_client
#      32 from llama_index.core.ingestion.cache import DEFAULT_CACHE_NAME, IngestionCache
#      33 from llama_index.core.ingestion.data_sources import (
#      34     ConfigurableDataSources,
#      35 )
#
# File c:\Users\Ghost\anaconda3\envs\genai360\lib\site-packages\llama_index\core\ingestion\api_utils.py:23
#      15 from llama_index.core.constants import (
#      16     DEFAULT_APP_URL,
#      17     DEFAULT_BASE_URL,
#      18     DEFAULT_PROJECT_NAME,
#      19 )
#      20 from llama_index.core.ingestion.data_sources import (
#      21     ConfiguredDataSource,
#      22 )
# ---> 23 from llama_index.core.ingestion.transformations import (
#      24     ConfiguredTransformation,
#      25 )
#      26 from llama_index.core.node_parser import SentenceSplitter
#      27 from llama_index.core.readers.base import ReaderConfig
#
# File c:\Users\Ghost\anaconda3\envs\genai360\lib\site-packages\llama_index\core\ingestion\transformations.py:255
#     250         pass
#     252     return ConfigurableComponent("ConfigurableTransformations", enum_members)
# --> 255 ConfigurableTransformations = build_configurable_transformation_enum()
#     257 T = TypeVar("T", bound=BaseComponent)
#     260 class ConfiguredTransformation(GenericModel, Generic[T]):
#
# File c:\Users\Ghost\anaconda3\envs\genai360\lib\site-packages\llama_index\core\ingestion\transformations.py:235, in build_configurable_transformation_enum()
#     232     pass
#     234 try:
# --> 235     from llama_index.embeddings.huggingface import (
#     236         HuggingFaceInferenceAPIEmbedding,
#     237     )  # pants: no-infer-dep
#     239     enum_members.append(
#     240         (
#     241             "HUGGINGFACE_API_EMBEDDING",
#    (...)
#     247         )
#     248     )
#     249 except ImportError:
#
# File c:\Users\Ghost\anaconda3\envs\genai360\lib\site-packages\llama_index\embeddings\huggingface\__init__.py:1
# ----> 1 from llama_index.embeddings.huggingface.base import (
#       2     HuggingFaceEmbedding,
#       3     HuggingFaceInferenceAPIEmbedding,
#       4     HuggingFaceInferenceAPIEmbeddings,
#       5 )
#       7 __all__ = [
#       8     "HuggingFaceEmbedding",
#       9     "HuggingFaceInferenceAPIEmbedding",
#      10     "HuggingFaceInferenceAPIEmbeddings",
#      11 ]
#
# File c:\Users\Ghost\anaconda3\envs\genai360\lib\site-packages\llama_index\embeddings\huggingface\base.py:25
#      19 from llama_index.embeddings.huggingface.pooling import Pooling
#      20 from llama_index.embeddings.huggingface.utils import (
#      21     DEFAULT_HUGGINGFACE_EMBEDDING_MODEL,
#      22     format_query,
#      23     format_text,
#      24 )
# ---> 25 from transformers import AutoModel, AutoTokenizer
#      27 if TYPE_CHECKING:
#      28     import torch
#
# File c:\Users\Ghost\anaconda3\envs\genai360\lib\site-packages\transformers\__init__.py:26
#      23 from typing import TYPE_CHECKING
#      25 # Check the dependencies satisfy the minimal versions required.
# ---> 26 from . import dependency_versions_check
#      27 from .utils import (
#      28     OptionalDependencyNotAvailable,
#      29     _LazyModule,
#    (...)
#      47     logging,
#      48 )
#      51 logger = logging.get_logger(__name__)  # pylint: disable=invalid-name
#
# File c:\Users\Ghost\anaconda3\envs\genai360\lib\site-packages\transformers\dependency_versions_check.py:16
#       1 # Copyright 2020 The HuggingFace Team. All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from .dependency_versions_table import deps
# ---> 16 from .utils.versions import require_version, require_version_core
#      19 # define which module versions we always want to check at run time
#      20 # (usually the ones defined in `install_requires` in setup.py)
#      21 #
#      22 # order specific notes:
#      23 # - tqdm must be checked before tokenizers
#      25 pkgs_to_check_at_runtime = [
#      26     "python",
#      27     "tqdm",
#    (...)
#      37     "pyyaml",
#      38 ]
#
# File c:\Users\Ghost\anaconda3\envs\genai360\lib\site-packages\transformers\utils\__init__.py:32
#      23 from .constants import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD, IMAGENET_STANDARD_MEAN, IMAGENET_STANDARD_STD
#      24 from .doc import (
#      25     add_code_sample_docstrings,
#      26     add_end_docstrings,
#    (...)
#      30     replace_return_docstrings,
#      31 )
# ---> 32 from .generic import (
#      33     ContextManagers,
#      34     ExplicitEnum,
#      35     ModelOutput,
#      36     PaddingStrategy,
#      37     TensorType,
#      38     add_model_info_to_auto_map,
#      39     cached_property,
#      40     can_return_loss,
#      41     expand_dims,
#      42     find_labels,
#      43     flatten_dict,
#      44     infer_framework,
#      45     is_jax_tensor,
#      46     is_numpy_array,
#      47     is_tensor,
#      48     is_tf_symbolic_tensor,
#      49     is_tf_tensor,
#      50     is_torch_device,
#      51     is_torch_dtype,
#      52     is_torch_tensor,
#      53     reshape,
#      54     squeeze,
#      55     strtobool,
#      56     tensor_size,
#      57     to_numpy,
#      58     to_py_obj,
#      59     transpose,
#      60     working_or_temp_dir,
#      61 )
#      62 from .hub import (
#      63     CLOUDFRONT_DISTRIB_PREFIX,
#      64     HF_MODULES_CACHE,
#    (...)
#      90     try_to_load_from_cache,
#      91 )
#      92 from .import_utils import (
#      93     ACCELERATE_MIN_VERSION,
#      94     ENV_VARS_TRUE_AND_AUTO_VALUES,
#    (...)
#     197     torch_only_method,
#     198 )
#
# File c:\Users\Ghost\anaconda3\envs\genai360\lib\site-packages\transformers\utils\generic.py:432
#     428         return tuple(self[k] for k in self.keys())
#     431 if is_torch_available():
# --> 432     import torch.utils._pytree as _torch_pytree
#     434     def _model_output_flatten(output: ModelOutput) -> Tuple[List[Any], "_torch_pytree.Context"]:
#     435         return list(output.values()), (type(output), list(output.keys()))
#
# File c:\Users\Ghost\anaconda3\envs\genai360\lib\site-packages\torch\__init__.py:1848
#    1846 from . import library
#    1847 if not TYPE_CHECKING:
# -> 1848     from . import _meta_registrations
#    1850 # Enable CUDA Sanitizer
#    1851 if 'TORCH_CUDA_SANITIZER' in os.environ:
#
# File c:\Users\Ghost\anaconda3\envs\genai360\lib\site-packages\torch\_meta_registrations.py:2146
#    2142     return out
#    2145 if torch._C._has_mkldnn:
# -> 2146     _meta_lib_dont_use_me_use_register_meta_for_mkldnn = torch.library.Library(
#    2147         "mkldnn", "IMPL", "Meta"
#    2148     )
#    2150     @register_meta(torch.ops.mkldnn._convolution_pointwise.default)
#    2151     def meta_mkldnn_convolution_default(
#    2152         input_tensor,
#    (...)
#    2161         algorithm,
#    2162     ):
#    2163         shape_out = calc_conv_nd_return_shape(
#    2164             input_tensor, weight, stride, padding, dilation, False, groups, []
#    2165         )
#
# File c:\Users\Ghost\anaconda3\envs\genai360\lib\site-packages\torch\library.py:61, in Library.__init__(self, ns, kind, dispatch_key)
#      58 if ns in _reserved_namespaces and (kind == "DEF" or kind == 'FRAGMENT'):
#      59     raise ValueError(ns, " is a reserved namespace. Please try creating a library with another name.")
# ---> 61 frame = traceback.extract_stack(limit=3)[0]
#      62 filename, lineno = frame.filename, frame.lineno
#      63 self.m: Optional[Any] = torch._C._dispatch_library(kind, ns, dispatch_key, filename, lineno)
#
# File c:\Users\Ghost\anaconda3\envs\genai360\lib\traceback.py:211, in extract_stack(f, limit)
#     209 if f is None:
#     210     f = sys._getframe().f_back
# --> 211 stack = StackSummary.extract(walk_stack(f), limit=limit)
#     212 stack.reverse()
#     213 return stack
#
# File c:\Users\Ghost\anaconda3\envs\genai360\lib\traceback.py:362, in StackSummary.extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     359     result.append(FrameSummary(
#     360         filename, lineno, name, lookup_line=False, locals=f_locals))
#     361 for filename in fnames:
# --> 362     linecache.checkcache(filename)
#     363 # If immediate lookup was desired, trigger lookups now.
#     364 if lookup_lines:
#
# File c:\Users\Ghost\anaconda3\envs\genai360\lib\linecache.py:72, in checkcache(filename)
#      70     continue   # no-op for files loaded via a __loader__
#      71 try:
# ---> 72     stat = os.stat(fullname)
#      73 except OSError:
#      74     cache.pop(filename, None)
#
# KeyboardInterrupt:

# %%
import llama_index.core.readers.base

# %%
from llama_index.readers.file import (
    DocxReader,
    EpubReader,
    HWPReader,
    ImageReader,
    IPYNBReader,
    MarkdownReader,
    MboxReader,
    PandasCSVReader,
    PDFReader,
    PptxReader,
    VideoAudioReader,
)
